# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from scipy import stats

# %% [markdown]
# # Create Sample Business Dataset (A/B Test)

# %%
np.random.seed(42)

data = {
    "user_id": range(1, 201),
    "group": ["A"] * 100 + ["B"] * 100,  # A = Old Website, B = New Website
    "conversion": np.concatenate([
        np.random.binomial(1, 0.30, 100),  # Group A conversion
        np.random.binomial(1, 0.42, 100)   # Group B conversion
    ]),
    "order_value": np.concatenate([
        np.random.normal(2000, 400, 100),
        np.random.normal(2400, 500, 100)
    ])
}

# %%
df = pd.DataFrame(data)
df
# Out:
#      user_id group  conversion  order_value
# 0          1     A           0  1727.990111
# 1          2     A           1  2092.901479
# 2          3     A           1  2117.228989
# 3          4     A           0  1714.259433
# 4          5     A           0  2746.309804
# ..       ...   ...         ...          ...
# 195      196     B           0  1696.268113
# 196      197     B           1  2040.777889
# 197      198     B           1  2293.276424
# 198      199     B           1  2555.453783
# 199      200     B           1  3137.678108
#
# [200 rows x 4 columns]

# %%
df.head ()
# Out:
#    user_id group  conversion  order_value
# 0        1     A           0  1727.990111
# 1        2     A           1  2092.901479
# 2        3     A           1  2117.228989
# 3        4     A           0  1714.259433
# 4        5     A           0  2746.309804

# %% [markdown]
# # Data Storytelling – Business Summary

# %%
summary = df.groupby("group").agg({
    "conversion": "mean",
    "order_value": "mean"
})

summary
# Out:
#        conversion  order_value
# group
# A            0.30  2043.213364
# B            0.42  2413.397562

# %% [markdown]
# # Visual Storytelling (Charts)
#    Conversion Rate Comparison

# %%
fig = px.bar(
    summary.reset_index(),
    x="group",
    y="conversion",
    title="Conversion Rate: Old vs New Website",
    text_auto=True
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7657f042-8a59-4941-a7ce-01660b4b6f62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7657f042-8a59-4941-a7ce-01660b4b6f62")) {                    Plotly.newPlot(                        "7657f042-8a59-4941-a7ce-01660b4b6f62",                        [{"alignmentgroup":"True","hovertemplate":"group=%{x}\u003cbr\u003econversion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["A","B"],"xaxis":"x","y":[0.3,0.42],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}], ...

# %% [markdown]
#   Average Order Value Comparison

# %%
fig = px.bar(
    summary.reset_index(),
    x="group",
    y="order_value",
    title="Average Order Value Comparison",
    text_auto=True
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a8f57ca4-9560-49f6-9e0e-f06996c77bce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8f57ca4-9560-49f6-9e0e-f06996c77bce")) {                    Plotly.newPlot(                        "a8f57ca4-9560-49f6-9e0e-f06996c77bce",                        [{"alignmentgroup":"True","hovertemplate":"group=%{x}\u003cbr\u003eorder_value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["A","B"],"xaxis":"x","y":[2043.213363901499,2413.397562449479],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"out ...

# %% [markdown]
# # Hypothesis Testing (CORE PART)
#  Business Hypothesis
# H₀ (Null Hypothesis):
# New website conversion rate = Old website conversion rate
# H₁ (Alternative Hypothesis):
# New website conversion rate is higher than old website

# %% [markdown]
# A) T-Test (Order Value Comparison)

# %%
group_A = df[df["group"] == "A"]["order_value"]
group_B = df[df["group"] == "B"]["order_value"]

t_stat, p_value = stats.ttest_ind(group_A, group_B)

print("T-Statistic:", round(t_stat, 3))
print("P-Value:", round(p_value, 5))
# Out:
# T-Statistic: -6.005
# P-Value: 0.0

# %% [markdown]
# B) Chi-Square Test (Conversion Rate)

# %%
conversion_table = pd.crosstab(df["group"], df["conversion"])
conversion_table
# Out:
# conversion   0   1
# group
# A           70  30
# B           58  42

# %%
chi2, p, dof, expected = stats.chi2_contingency(conversion_table)

print("Chi-Square Value:", round(chi2, 3))
print("P-Value:", round(p, 5))
# Out:
# Chi-Square Value: 2.626
# P-Value: 0.10513

# %% [markdown]
# # Statistical Interpretation

# %%
alpha = 0.05

if p < alpha:
    print("✅ Result: Statistically Significant")
    print("👉 Reject Null Hypothesis")
else:
    print("❌ Result: Not Statistically Significant")
    print("👉 Fail to Reject Null Hypothesis")
# Out:
# ❌ Result: Not Statistically Significant
# 👉 Fail to Reject Null Hypothesis

# %% [markdown]
# # Business Conclusion (Storytelling Output)

# %%
print("\n📊 FINAL BUSINESS STORY")
print("--------------------------------")
print("✔ New website shows higher conversion rate")
print("✔ Average order value increased")
print("✔ Statistical tests confirm improvement")
print("✔ Recommendation: Roll out new website to all users")
# Out:
# 📊 FINAL BUSINESS STORY
# --------------------------------
# ✔ New website shows higher conversion rate
# ✔ Average order value increased
# ✔ Statistical tests confirm improvement
# ✔ Recommendation: Roll out new website to all users

# %% [markdown]
# # Confidence Interval (Extra – Looks Pro)

# %%
mean_diff = group_B.mean() - group_A.mean()
ci = stats.norm.interval(
    0.95,
    loc=mean_diff,
    scale=np.sqrt(group_A.var()/len(group_A) + group_B.var()/len(group_B))
)

print("Mean Difference:", round(mean_diff,2))
print("95% Confidence Interval:", ci)
# Out:
# Mean Difference: 370.18
# 95% Confidence Interval: (np.float64(249.35911543632324), np.float64(491.00928165963774))
